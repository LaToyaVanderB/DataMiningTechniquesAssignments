# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import seaborn as sns
sns.set()
sns.set(rc={'figure.figsize':(11, 4)})

# %% [markdown]
# ## Load data

# %%
samples = pd.read_csv("data/raw/dataset_mood_smartphone.csv", 
                      sep=',', 
                      index_col=0, 
                      parse_dates=["time"],
                      dtype={"id": "category", "variable": "category"})
samples = samples.rename(columns={"time": "datetime"})
samples
# Out:
#               id                datetime        variable   value
# 1        AS14.01 2014-02-26 13:00:00.000            mood   6.000
# 2        AS14.01 2014-02-26 15:00:00.000            mood   6.000
# 3        AS14.01 2014-02-26 18:00:00.000            mood   6.000
# 4        AS14.01 2014-02-26 21:00:00.000            mood   7.000
# 5        AS14.01 2014-02-27 09:00:00.000            mood   6.000
# ...          ...                     ...             ...     ...
# 2770399  AS14.30 2014-04-11 07:51:16.948  appCat.weather   8.032
# 2772465  AS14.30 2014-04-19 11:00:32.747  appCat.weather   3.008
# 2774026  AS14.30 2014-04-26 10:19:07.434  appCat.weather   7.026
# 2774133  AS14.30 2014-04-27 00:44:48.450  appCat.weather  23.033
# 2784435  AS14.32 2014-04-07 18:25:14.036  appCat.weather  22.431
#
# [376912 rows x 4 columns]

# %% [markdown]
# ## Remove duplicates

# %%
dupes = samples.duplicated(subset=['datetime', 'variable', 'id'], keep='last')
samples_deduped = samples[dupes == False]

# %% [markdown]
# ## Remove negative values for appCat.* variables

# %%
samples_cleaned = samples_deduped[(~(samples_deduped['variable'].str.startswith('app'))) |
                                   ((samples_deduped['variable'].str.startswith('app')) & 
                                   (samples_deduped['value'] > 0))]
samples_cleaned
# Out:
#               id                datetime        variable   value
# 1        AS14.01 2014-02-26 13:00:00.000            mood   6.000
# 2        AS14.01 2014-02-26 15:00:00.000            mood   6.000
# 3        AS14.01 2014-02-26 18:00:00.000            mood   6.000
# 4        AS14.01 2014-02-26 21:00:00.000            mood   7.000
# 5        AS14.01 2014-02-27 09:00:00.000            mood   6.000
# ...          ...                     ...             ...     ...
# 2770399  AS14.30 2014-04-11 07:51:16.948  appCat.weather   8.032
# 2772465  AS14.30 2014-04-19 11:00:32.747  appCat.weather   3.008
# 2774026  AS14.30 2014-04-26 10:19:07.434  appCat.weather   7.026
# 2774133  AS14.30 2014-04-27 00:44:48.450  appCat.weather  23.033
# 2784435  AS14.32 2014-04-07 18:25:14.036  appCat.weather  22.431
#
# [376865 rows x 4 columns]

# %% [markdown]
# ## Remove outliers

# %%
## Todo

# %% [markdown]
# ## Pivot the data to a time indexed data frame
# https://pandas.pydata.org/docs/user_guide/reshaping.html

# %%
vdata = samples_cleaned.pivot(index="datetime", columns=["id", "variable"], values="value")
vdata
# Out:
# id                      AS14.01 AS14.02 AS14.03 AS14.05 AS14.06 AS14.07  \
# variable                   mood    mood    mood    mood    mood    mood
# datetime
# 2014-02-17 07:00:52.197     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 07:12:13.631     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 07:49:19.635     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 08:57:16.313     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 08:58:58.471     NaN     NaN     NaN     NaN     NaN     NaN
# ...                         ...     ...     ...     ...     ...     ...
# 2014-06-08 11:03:34.453     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-08 11:04:20.233     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-08 11:04:36.299     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-08 11:04:46.335     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-09 00:00:00.000     NaN     NaN     NaN     NaN     NaN     NaN
#
# id                      AS14.08 AS14.09 AS14.12 AS14.13  ...        AS14.06  \
# variable                   mood    mood    mood    mood  ... appCat.weather
# datetime                                                 ...
# 2014-02-17 07:00:52.197     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 07:12:13.631     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 07:49:19.635     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 08:57:16.313     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 08:58:58.471     NaN     NaN     NaN     NaN  ...            NaN
# ...                         ...     ...     ...     ...  ...            ...
# 2014-06-08 11:03:34.453     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-08 11:04:20.233     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-08 11:04:36.299     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-08 11:04:46.335     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-09 00:00:00.000     NaN     NaN     NaN     NaN  ...            NaN
#
# id                             AS14.09        AS14.12        AS14.16  \
# variable                appCat.weather appCat.weather appCat.weather
# datetime
# 2014-02-17 07:00:52.197            NaN            NaN            NaN
# 2014-02-17 07:12:13.631            NaN            NaN            NaN
# 2014-02-17 07:49:19.635            NaN            NaN            NaN
# 2014-02-17 08:57:16.313            NaN            NaN            NaN
# 2014-02-17 08:58:58.471            NaN            NaN            NaN
# ...                                ...            ...            ...
# 2014-06-08 11:03:34.453            NaN            NaN            NaN
# 2014-06-08 11:04:20.233            NaN            NaN            NaN
# 2014-06-08 11:04:36.299            NaN            NaN            NaN
# 2014-06-08 11:04:46.335            NaN            NaN            NaN
# 2014-06-09 00:00:00.000            NaN            NaN            NaN
#
# id                             AS14.25        AS14.26        AS14.27  \
# variable                appCat.weather appCat.weather appCat.weather
# datetime
# 2014-02-17 07:00:52.197            NaN            NaN            NaN
# 2014-02-17 07:12:13.631            NaN            NaN            NaN
# 2014-02-17 07:49:19.635            NaN            NaN            NaN
# 2014-02-17 08:57:16.313            NaN            NaN            NaN
# 2014-02-17 08:58:58.471            NaN            NaN            NaN
# ...                                ...            ...            ...
# 2014-06-08 11:03:34.453            NaN            NaN            NaN
# 2014-06-08 11:04:20.233            NaN            NaN            NaN
# 2014-06-08 11:04:36.299            NaN            NaN            NaN
# 2014-06-08 11:04:46.335            NaN            NaN            NaN
# 2014-06-09 00:00:00.000            NaN            NaN            NaN
#
# id                             AS14.28        AS14.30        AS14.32
# variable                appCat.weather appCat.weather appCat.weather
# datetime
# 2014-02-17 07:00:52.197            NaN            NaN            NaN
# 2014-02-17 07:12:13.631            NaN            NaN            NaN
# 2014-02-17 07:49:19.635            NaN            NaN            NaN
# 2014-02-17 08:57:16.313            NaN            NaN            NaN
# 2014-02-17 08:58:58.471            NaN            NaN            NaN
# ...                                ...            ...            ...
# 2014-06-08 11:03:34.453            NaN            NaN            NaN
# 2014-06-08 11:04:20.233            NaN            NaN            NaN
# 2014-06-08 11:04:36.299            NaN            NaN            NaN
# 2014-06-08 11:04:46.335            NaN            NaN            NaN
# 2014-06-09 00:00:00.000            NaN            NaN            NaN
#
# [336903 rows x 464 columns]

# %%
ids = list(samples["id"].unique())
d = {}
for id in ids:
    d[(id, "mood_1D")] = vdata.loc[:, (id , 'mood')].resample('D').mean()
    d[(id, "valence_1D")] = vdata.loc[:, (id , 'circumplex.valence')].resample('D').mean()
    d[(id, "arousal_1D")] = vdata.loc[:, (id , 'circumplex.arousal')].resample('D').mean()
    d[(id, "social_1D")] = vdata.loc[:, (id , 'appCat.social')].resample('D').sum()
    d[(id, "social_rolling_5D")] = vdata.loc[:, (id , 'appCat.social')].rolling('5D').sum().resample('D').mean() / 5
    d[(id, "social_rolling_10D")] = vdata.loc[:, (id , 'appCat.social')].rolling('10D').sum().resample('D').mean() / 10
    
    mood = vdata.loc[:, (id, 'mood')]
    mood.dropna(inplace=True)
    d[(id, 'mood_first')] = mood.resample('D').first()
    d[(id, 'mood_last')] = mood.resample('D').last()
    d[(id, 'mood_delta')] = features.loc[:, (id, 'mood_last')] - features.loc[:, (id, 'mood_first')]
    
    d[(id, "target")] = vdata.loc[:, (id , 'mood')].resample('D').mean().shift(-1)
    d[(id, "target_binary")] = (d[(id, "target")] >= 7).astype(int)
    
features = pd.DataFrame(d)
features
# Out:
#            AS14.01                                                    \
#            mood_1D valence_1D arousal_1D social_1D social_rolling_5D
# datetime
# 2014-02-17     NaN        NaN        NaN       0.0               NaN
# 2014-02-18     NaN        NaN        NaN       0.0               NaN
# 2014-02-19     NaN        NaN        NaN       0.0               NaN
# 2014-02-20     NaN        NaN        NaN       0.0               NaN
# 2014-02-21     NaN        NaN        NaN       0.0               NaN
# ...            ...        ...        ...       ...               ...
# 2014-06-05     NaN        NaN        NaN       0.0               NaN
# 2014-06-06     NaN        NaN        NaN       0.0               NaN
# 2014-06-07     NaN        NaN        NaN       0.0               NaN
# 2014-06-08     NaN        NaN        NaN       0.0               NaN
# 2014-06-09     NaN        NaN        NaN       0.0               NaN
#
#                                                                       ...  \
#            social_rolling_10D mood_first mood_last mood_delta target  ...
# datetime                                                              ...
# 2014-02-17                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-18                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-19                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-20                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-21                NaN        NaN       NaN        NaN    NaN  ...
# ...                       ...        ...       ...        ...    ...  ...
# 2014-06-05                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-06                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-07                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-08                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-09                NaN        NaN       NaN        NaN    NaN  ...
#
#               AS14.33                                         \
#            valence_1D arousal_1D social_1D social_rolling_5D
# datetime
# 2014-02-17        NaN        NaN       0.0               NaN
# 2014-02-18        NaN        NaN       0.0               NaN
# 2014-02-19        NaN        NaN       0.0               NaN
# 2014-02-20        NaN        NaN       0.0               NaN
# 2014-02-21        NaN        NaN       0.0               NaN
# ...               ...        ...       ...               ...
# 2014-06-05        NaN        NaN       0.0               NaN
# 2014-06-06        NaN        NaN       0.0               NaN
# 2014-06-07        NaN        NaN       0.0               NaN
# 2014-06-08        NaN        NaN       0.0               NaN
# 2014-06-09        NaN        NaN       0.0               NaN
#
#                                                                       \
#            social_rolling_10D mood_first mood_last mood_delta target
# datetime
# 2014-02-17                NaN        NaN       NaN        NaN    NaN
# 2014-02-18                NaN        NaN       NaN        NaN    NaN
# 2014-02-19                NaN        NaN       NaN        NaN    NaN
# 2014-02-20                NaN        NaN       NaN        NaN    NaN
# 2014-02-21                NaN        NaN       NaN        NaN    NaN
# ...                       ...        ...       ...        ...    ...
# 2014-06-05        1497.527814        NaN       NaN        NaN    NaN
# 2014-06-06        1135.224557        NaN       NaN        NaN    NaN
# 2014-06-07         885.347048        NaN       NaN        NaN    NaN
# 2014-06-08         425.951245        NaN       NaN        NaN    NaN
# 2014-06-09         316.640900        NaN       NaN        NaN    NaN
#
#
#            target_binary
# datetime
# 2014-02-17             0
# 2014-02-18             0
# 2014-02-19             0
# 2014-02-20             0
# 2014-02-21             0
# ...                  ...
# 2014-06-05             0
# 2014-06-06             0
# 2014-06-07             0
# 2014-06-08             0
# 2014-06-09             0
#
# [113 rows x 297 columns]

# %%
features.index
# Out:
# DatetimeIndex(['2014-02-17', '2014-02-18', '2014-02-19', '2014-02-20',
#                '2014-02-21', '2014-02-22', '2014-02-23', '2014-02-24',
#                '2014-02-25', '2014-02-26',
#                ...
#                '2014-05-31', '2014-06-01', '2014-06-02', '2014-06-03',
#                '2014-06-04', '2014-06-05', '2014-06-06', '2014-06-07',
#                '2014-06-08', '2014-06-09'],
#               dtype='datetime64[ns]', name='datetime', length=113, freq='D')

# %%
features.columns.tolist()
# Out:
# [('AS14.01', 'mood_1D'),
#  ('AS14.01', 'valence_1D'),
#  ('AS14.01', 'arousal_1D'),
#  ('AS14.01', 'social_1D'),
#  ('AS14.01', 'social_rolling_5D'),
#  ('AS14.01', 'social_rolling_10D'),
#  ('AS14.01', 'mood_first'),
#  ('AS14.01', 'mood_last'),
#  ('AS14.01', 'mood_delta'),
#  ('AS14.01', 'target'),
#  ('AS14.01', 'target_binary'),
#  ('AS14.02', 'mood_1D'),
#  ('AS14.02', 'valence_1D'),
#  ('AS14.02', 'arousal_1D'),
#  ('AS14.02', 'social_1D'),
#  ('AS14.02', 'social_rolling_5D'),
#  ('AS14.02', 'social_rolling_10D'),
#  ('AS14.02', 'mood_first'),
#  ('AS14.02', 'mood_last'),
#  ('AS14.02', 'mood_delta'),
#  ('AS14.02', 'target'),
#  ('AS14.02', 'target_binary'),
#  ('AS14.03', 'mood_1D'),
#  ('AS14.03', 'valence_1D'),
#  ('AS14.03', 'arousal_1D'),
#  ('AS14.03', 'social_1D'),
#  ('AS14.03', 'social_rolling_5D'),
#  ('AS14.03', 'social_rolling_10D'),
#  ('AS14.03', 'mood_first'),
#  ('AS14.03', 'mood_last'),
#  ('AS14.03', 'mood_delta'),
#  ('AS14.03', 'target'),
#  ('AS14.03', 'target_binary'),
#  ('AS14.05', 'mood_1D'),
#  ('AS14.05', 'valence_1D'),
#  ('AS14.05', 'arousal_1D'),
#  ('AS14.05', 'social_1D'),
#  ('AS14.05', 'social_rolling_5D'),
#  ('AS14.05', 'social_rolling_10D'),
#  ('AS14.05', 'mood_first'),
#  ('AS14.05', 'mood_last'),
#  ('AS14.05', 'mood_delta'),
#  ('AS14.05', 'target'),
#  ('AS14.05', 'target_binary'),
#  ('AS14.06', 'mood_1D'),
#  ('AS14.06', 'valence_1D'),
#  ('AS14.06', 'arousal_1D'),
#  ('AS14.06', 'social_1D'),
#  ('AS14.06', 'social_rolling_5D'),
#  ('AS14.06', 'social_rolling_10D'),
#  ('AS14.06', 'mood_first'),
#  ('AS14.06', 'mood_last'),
#  ('AS14.06', 'mood_delta'),
#  ('AS14.06', 'target'),
#  ('AS14.06', 'target_binary'),
#  ('AS14.07', 'mood_1D'),
#  ('AS14.07', 'valence_1D'),
#  ('AS14.07', 'arousal_1D'),
#  ('AS14.07', 'social_1D'),
#  ('AS14.07', 'social_rolling_5D'),
#  ('AS14.07', 'social_rolling_10D'),
#  ('AS14.07', 'mood_first'),
#  ('AS14.07', 'mood_last'),
#  ('AS14.07', 'mood_delta'),
#  ('AS14.07', 'target'),
#  ('AS14.07', 'target_binary'),
#  ('AS14.08', 'mood_1D'),
#  ('AS14.08', 'valence_1D'),
#  ('AS14.08', 'arousal_1D'),
#  ('AS14.08', 'social_1D'),
#  ('AS14.08', 'social_rolling_5D'),
#  ('AS14.08', 'social_rolling_10D'),
#  ('AS14.08', 'mood_first'),
#  ('AS14.08', 'mood_last'),
#  ('AS14.08', 'mood_delta'),
#  ('AS14.08', 'target'),
#  ('AS14.08', 'target_binary'),
#  ('AS14.09', 'mood_1D'),
#  ('AS14.09', 'valence_1D'),
#  ('AS14.09', 'arousal_1D'),
#  ('AS14.09', 'social_1D'),
#  ('AS14.09', 'social_rolling_5D'),
#  ('AS14.09', 'social_rolling_10D'),
#  ('AS14.09', 'mood_first'),
#  ('AS14.09', 'mood_last'),
#  ('AS14.09', 'mood_delta'),
#  ('AS14.09', 'target'),
#  ('AS14.09', 'target_binary'),
#  ('AS14.12', 'mood_1D'),
#  ('AS14.12', 'valence_1D'),
#  ('AS14.12', 'arousal_1D'),
#  ('AS14.12', 'social_1D'),
#  ('AS14.12', 'social_rolling_5D'),
#  ('AS14.12', 'social_rolling_10D'),
#  ('AS14.12', 'mood_first'),
#  ('AS14.12', 'mood_last'),
#  ('AS14.12', 'mood_delta'),
#  ('AS14.12', 'target'),
#  ('AS14.12', 'target_binary'),
#  ('AS14.13', 'mood_1D'),
#  ('AS14.13', 'valence_1D'),
#  ('AS14.13', 'arousal_1D'),
#  ('AS14.13', 'social_1D'),
#  ('AS14.13', 'social_rolling_5D'),
#  ('AS14.13', 'social_rolling_10D'),
#  ('AS14.13', 'mood_first'),
#  ('AS14.13', 'mood_last'),
#  ('AS14.13', 'mood_delta'),
#  ('AS14.13', 'target'),
#  ('AS14.13', 'target_binary'),
#  ('AS14.14', 'mood_1D'),
#  ('AS14.14', 'valence_1D'),
#  ('AS14.14', 'arousal_1D'),
#  ('AS14.14', 'social_1D'),
#  ('AS14.14', 'social_rolling_5D'),
#  ('AS14.14', 'social_rolling_10D'),
#  ('AS14.14', 'mood_first'),
#  ('AS14.14', 'mood_last'),
#  ('AS14.14', 'mood_delta'),
#  ('AS14.14', 'target'),
#  ('AS14.14', 'target_binary'),
#  ('AS14.15', 'mood_1D'),
#  ('AS14.15', 'valence_1D'),
#  ('AS14.15', 'arousal_1D'),
#  ('AS14.15', 'social_1D'),
#  ('AS14.15', 'social_rolling_5D'),
#  ('AS14.15', 'social_rolling_10D'),
#  ('AS14.15', 'mood_first'),
#  ('AS14.15', 'mood_last'),
#  ('AS14.15', 'mood_delta'),
#  ('AS14.15', 'target'),
#  ('AS14.15', 'target_binary'),
#  ('AS14.16', 'mood_1D'),
#  ('AS14.16', 'valence_1D'),
#  ('AS14.16', 'arousal_1D'),
#  ('AS14.16', 'social_1D'),
#  ('AS14.16', 'social_rolling_5D'),
#  ('AS14.16', 'social_rolling_10D'),
#  ('AS14.16', 'mood_first'),
#  ('AS14.16', 'mood_last'),
#  ('AS14.16', 'mood_delta'),
#  ('AS14.16', 'target'),
#  ('AS14.16', 'target_binary'),
#  ('AS14.17', 'mood_1D'),
#  ('AS14.17', 'valence_1D'),
#  ('AS14.17', 'arousal_1D'),
#  ('AS14.17', 'social_1D'),
#  ('AS14.17', 'social_rolling_5D'),
#  ('AS14.17', 'social_rolling_10D'),
#  ('AS14.17', 'mood_first'),
#  ('AS14.17', 'mood_last'),
#  ('AS14.17', 'mood_delta'),
#  ('AS14.17', 'target'),
#  ('AS14.17', 'target_binary'),
#  ('AS14.19', 'mood_1D'),
#  ('AS14.19', 'valence_1D'),
#  ('AS14.19', 'arousal_1D'),
#  ('AS14.19', 'social_1D'),
#  ('AS14.19', 'social_rolling_5D'),
#  ('AS14.19', 'social_rolling_10D'),
#  ('AS14.19', 'mood_first'),
#  ('AS14.19', 'mood_last'),
#  ('AS14.19', 'mood_delta'),
#  ('AS14.19', 'target'),
#  ('AS14.19', 'target_binary'),
#  ('AS14.20', 'mood_1D'),
#  ('AS14.20', 'valence_1D'),
#  ('AS14.20', 'arousal_1D'),
#  ('AS14.20', 'social_1D'),
#  ('AS14.20', 'social_rolling_5D'),
#  ('AS14.20', 'social_rolling_10D'),
#  ('AS14.20', 'mood_first'),
#  ('AS14.20', 'mood_last'),
#  ('AS14.20', 'mood_delta'),
#  ('AS14.20', 'target'),
#  ('AS14.20', 'target_binary'),
#  ('AS14.23', 'mood_1D'),
#  ('AS14.23', 'valence_1D'),
#  ('AS14.23', 'arousal_1D'),
#  ('AS14.23', 'social_1D'),
#  ('AS14.23', 'social_rolling_5D'),
#  ('AS14.23', 'social_rolling_10D'),
#  ('AS14.23', 'mood_first'),
#  ('AS14.23', 'mood_last'),
#  ('AS14.23', 'mood_delta'),
#  ('AS14.23', 'target'),
#  ('AS14.23', 'target_binary'),
#  ('AS14.24', 'mood_1D'),
#  ('AS14.24', 'valence_1D'),
#  ('AS14.24', 'arousal_1D'),
#  ('AS14.24', 'social_1D'),
#  ('AS14.24', 'social_rolling_5D'),
#  ('AS14.24', 'social_rolling_10D'),
#  ('AS14.24', 'mood_first'),
#  ('AS14.24', 'mood_last'),
#  ('AS14.24', 'mood_delta'),
#  ('AS14.24', 'target'),
#  ('AS14.24', 'target_binary'),
#  ('AS14.25', 'mood_1D'),
#  ('AS14.25', 'valence_1D'),
#  ('AS14.25', 'arousal_1D'),
#  ('AS14.25', 'social_1D'),
#  ('AS14.25', 'social_rolling_5D'),
#  ('AS14.25', 'social_rolling_10D'),
#  ('AS14.25', 'mood_first'),
#  ('AS14.25', 'mood_last'),
#  ('AS14.25', 'mood_delta'),
#  ('AS14.25', 'target'),
#  ('AS14.25', 'target_binary'),
#  ('AS14.26', 'mood_1D'),
#  ('AS14.26', 'valence_1D'),
#  ('AS14.26', 'arousal_1D'),
#  ('AS14.26', 'social_1D'),
#  ('AS14.26', 'social_rolling_5D'),
#  ('AS14.26', 'social_rolling_10D'),
#  ('AS14.26', 'mood_first'),
#  ('AS14.26', 'mood_last'),
#  ('AS14.26', 'mood_delta'),
#  ('AS14.26', 'target'),
#  ('AS14.26', 'target_binary'),
#  ('AS14.27', 'mood_1D'),
#  ('AS14.27', 'valence_1D'),
#  ('AS14.27', 'arousal_1D'),
#  ('AS14.27', 'social_1D'),
#  ('AS14.27', 'social_rolling_5D'),
#  ('AS14.27', 'social_rolling_10D'),
#  ('AS14.27', 'mood_first'),
#  ('AS14.27', 'mood_last'),
#  ('AS14.27', 'mood_delta'),
#  ('AS14.27', 'target'),
#  ('AS14.27', 'target_binary'),
#  ('AS14.28', 'mood_1D'),
#  ('AS14.28', 'valence_1D'),
#  ('AS14.28', 'arousal_1D'),
#  ('AS14.28', 'social_1D'),
#  ('AS14.28', 'social_rolling_5D'),
#  ('AS14.28', 'social_rolling_10D'),
#  ('AS14.28', 'mood_first'),
#  ('AS14.28', 'mood_last'),
#  ('AS14.28', 'mood_delta'),
#  ('AS14.28', 'target'),
#  ('AS14.28', 'target_binary'),
#  ('AS14.29', 'mood_1D'),
#  ('AS14.29', 'valence_1D'),
#  ('AS14.29', 'arousal_1D'),
#  ('AS14.29', 'social_1D'),
#  ('AS14.29', 'social_rolling_5D'),
#  ('AS14.29', 'social_rolling_10D'),
#  ('AS14.29', 'mood_first'),
#  ('AS14.29', 'mood_last'),
#  ('AS14.29', 'mood_delta'),
#  ('AS14.29', 'target'),
#  ('AS14.29', 'target_binary'),
#  ('AS14.30', 'mood_1D'),
#  ('AS14.30', 'valence_1D'),
#  ('AS14.30', 'arousal_1D'),
#  ('AS14.30', 'social_1D'),
#  ('AS14.30', 'social_rolling_5D'),
#  ('AS14.30', 'social_rolling_10D'),
#  ('AS14.30', 'mood_first'),
#  ('AS14.30', 'mood_last'),
#  ('AS14.30', 'mood_delta'),
#  ('AS14.30', 'target'),
#  ('AS14.30', 'target_binary'),
#  ('AS14.31', 'mood_1D'),
#  ('AS14.31', 'valence_1D'),
#  ('AS14.31', 'arousal_1D'),
#  ('AS14.31', 'social_1D'),
#  ('AS14.31', 'social_rolling_5D'),
#  ('AS14.31', 'social_rolling_10D'),
#  ('AS14.31', 'mood_first'),
#  ('AS14.31', 'mood_last'),
#  ('AS14.31', 'mood_delta'),
#  ('AS14.31', 'target'),
#  ('AS14.31', 'target_binary'),
#  ('AS14.32', 'mood_1D'),
#  ('AS14.32', 'valence_1D'),
#  ('AS14.32', 'arousal_1D'),
#  ('AS14.32', 'social_1D'),
#  ('AS14.32', 'social_rolling_5D'),
#  ('AS14.32', 'social_rolling_10D'),
#  ('AS14.32', 'mood_first'),
#  ('AS14.32', 'mood_last'),
#  ('AS14.32', 'mood_delta'),
#  ('AS14.32', 'target'),
#  ('AS14.32', 'target_binary'),
#  ('AS14.33', 'mood_1D'),
#  ('AS14.33', 'valence_1D'),
#  ('AS14.33', 'arousal_1D'),
#  ('AS14.33', 'social_1D'),
#  ('AS14.33', 'social_rolling_5D'),
#  ('AS14.33', 'social_rolling_10D'),
#  ('AS14.33', 'mood_first'),
#  ('AS14.33', 'mood_last'),
#  ('AS14.33', 'mood_delta'),
#  ('AS14.33', 'target'),
#  ('AS14.33', 'target_binary')]

# %%
features
# Out:
#            AS14.01                                                    \
#            mood_1D valence_1D arousal_1D social_1D social_rolling_5D
# datetime
# 2014-02-17     NaN        NaN        NaN       0.0               NaN
# 2014-02-18     NaN        NaN        NaN       0.0               NaN
# 2014-02-19     NaN        NaN        NaN       0.0               NaN
# 2014-02-20     NaN        NaN        NaN       0.0               NaN
# 2014-02-21     NaN        NaN        NaN       0.0               NaN
# ...            ...        ...        ...       ...               ...
# 2014-06-05     NaN        NaN        NaN       0.0               NaN
# 2014-06-06     NaN        NaN        NaN       0.0               NaN
# 2014-06-07     NaN        NaN        NaN       0.0               NaN
# 2014-06-08     NaN        NaN        NaN       0.0               NaN
# 2014-06-09     NaN        NaN        NaN       0.0               NaN
#
#                                                                       ...  \
#            social_rolling_10D mood_first mood_last mood_delta target  ...
# datetime                                                              ...
# 2014-02-17                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-18                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-19                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-20                NaN        NaN       NaN        NaN    NaN  ...
# 2014-02-21                NaN        NaN       NaN        NaN    NaN  ...
# ...                       ...        ...       ...        ...    ...  ...
# 2014-06-05                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-06                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-07                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-08                NaN        NaN       NaN        NaN    NaN  ...
# 2014-06-09                NaN        NaN       NaN        NaN    NaN  ...
#
#               AS14.33                                         \
#            valence_1D arousal_1D social_1D social_rolling_5D
# datetime
# 2014-02-17        NaN        NaN       0.0               NaN
# 2014-02-18        NaN        NaN       0.0               NaN
# 2014-02-19        NaN        NaN       0.0               NaN
# 2014-02-20        NaN        NaN       0.0               NaN
# 2014-02-21        NaN        NaN       0.0               NaN
# ...               ...        ...       ...               ...
# 2014-06-05        NaN        NaN       0.0               NaN
# 2014-06-06        NaN        NaN       0.0               NaN
# 2014-06-07        NaN        NaN       0.0               NaN
# 2014-06-08        NaN        NaN       0.0               NaN
# 2014-06-09        NaN        NaN       0.0               NaN
#
#                                                                       \
#            social_rolling_10D mood_first mood_last mood_delta target
# datetime
# 2014-02-17                NaN        NaN       NaN        NaN    NaN
# 2014-02-18                NaN        NaN       NaN        NaN    NaN
# 2014-02-19                NaN        NaN       NaN        NaN    NaN
# 2014-02-20                NaN        NaN       NaN        NaN    NaN
# 2014-02-21                NaN        NaN       NaN        NaN    NaN
# ...                       ...        ...       ...        ...    ...
# 2014-06-05        1497.527814        NaN       NaN        NaN    NaN
# 2014-06-06        1135.224557        NaN       NaN        NaN    NaN
# 2014-06-07         885.347048        NaN       NaN        NaN    NaN
# 2014-06-08         425.951245        NaN       NaN        NaN    NaN
# 2014-06-09         316.640900        NaN       NaN        NaN    NaN
#
#
#            target_binary
# datetime
# 2014-02-17             0
# 2014-02-18             0
# 2014-02-19             0
# 2014-02-20             0
# 2014-02-21             0
# ...                  ...
# 2014-06-05             0
# 2014-06-06             0
# 2014-06-07             0
# 2014-06-08             0
# 2014-06-09             0
#
# [113 rows x 297 columns]

# %%
id = 'AS14.01'
start, end = '2014-03-22', '2014-05-01'
data = features[id]

fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(11, 13))
for ax in axs:
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
fig.suptitle('Features')

sns.lineplot(ax=axs[0], data=data['mood_1D'].loc[start:end], label='mood, day mean', marker='o')
sns.lineplot(ax=axs[0], data=data['target'].loc[start:end], label='target, next day mean', marker='o')
sns.lineplot(ax=axs[0], data=data['target_binary'].loc[start:end], label='target, next day binary', marker='o')

sns.lineplot(ax=axs[1], data=data['mood_first'].loc[start:end], label='mood, day first', marker='o')
sns.lineplot(ax=axs[1], data=data['mood_last'].loc[start:end], label='mood, day last', marker='o')
sns.lineplot(ax=axs[1], data=data['mood_delta'].loc[start:end], label='mood, day delta', marker='o')

sns.lineplot(ax=axs[2], data=data['valence_1D'].loc[start:end], label='valence, day mean', marker='o')
sns.lineplot(ax=axs[2], data=data['arousal_1D'].loc[start:end], label='arousal, day mean', marker='o')

sns.lineplot(ax=axs[3], data=data['social_1D'].loc[start:end], marker='o', label='social, day sum')
sns.lineplot(ax=axs[3], data=data['social_rolling_5D'].loc[start:end], marker='o', label='social, 5-day rolling sum, day mean ');
sns.lineplot(ax=axs[3], data=data['social_rolling_10D'].loc[start:end], marker='o', label='social, 10-day rolling sum, day mean ');

# %%
data.plot(subplots=True, figsize=(6, 12), title=id);
