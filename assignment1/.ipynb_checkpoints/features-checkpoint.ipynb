# %% [markdown]
# Papers:
# -
#
# Preprocessing:
# - [DONE] remove zones with no data
# - [DONE] detect and handle missing values (imputation methods: ffill)
# - [DONE] create features -> features.ipynb
# - [DONE] Remove last (longest_allowed_gap - 1) values after imputation
# - [TODO] Impute "ASBENT" value instead of "nan"
# - [TODO] detect and handle outliers
# - [TODO] normalize/standardize
#
# Algorithms to try:
# - [TODO] Linear model
# - [OPEN] Random forests
# - [TODO] SVM
# - [TODO] RNN
#
# Present results:
# - [DONE] Present training results for all patients in one plot

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import seaborn as sns
sns.set()
sns.set(rc={'figure.figsize':(11, 4)})

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

from statistics import mean, stdev

# Decision trees
from sklearn.tree import DecisionTreeClassifier
# Random Forests"
from sklearn.ensemble import RandomForestClassifier
# Grid search
from sklearn.model_selection import GridSearchCV
# Standardize
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load data

# %%
samples = pd.read_csv("data/raw/dataset_mood_smartphone.csv", 
                      sep=',', 
                      index_col=0, 
                      parse_dates=["time"],
                      dtype={"id": "category", "variable": "category"})
samples = samples.rename(columns={"time": "datetime"})
samples
# Out:
#               id                datetime        variable   value
# 1        AS14.01 2014-02-26 13:00:00.000            mood   6.000
# 2        AS14.01 2014-02-26 15:00:00.000            mood   6.000
# 3        AS14.01 2014-02-26 18:00:00.000            mood   6.000
# 4        AS14.01 2014-02-26 21:00:00.000            mood   7.000
# 5        AS14.01 2014-02-27 09:00:00.000            mood   6.000
# ...          ...                     ...             ...     ...
# 2770399  AS14.30 2014-04-11 07:51:16.948  appCat.weather   8.032
# 2772465  AS14.30 2014-04-19 11:00:32.747  appCat.weather   3.008
# 2774026  AS14.30 2014-04-26 10:19:07.434  appCat.weather   7.026
# 2774133  AS14.30 2014-04-27 00:44:48.450  appCat.weather  23.033
# 2784435  AS14.32 2014-04-07 18:25:14.036  appCat.weather  22.431
#
# [376912 rows x 4 columns]

# %% [markdown]
# ## Remove duplicates

# %%
dupes = samples.duplicated(subset=['datetime', 'variable', 'id'], keep='last')
samples_deduped = samples[dupes == False]

# %% [markdown]
# ## Remove negative values for appCat.* variables

# %%
samples_cleaned = samples_deduped[(~(samples_deduped['variable'].str.startswith('app'))) |
                                   ((samples_deduped['variable'].str.startswith('app')) & 
                                   (samples_deduped['value'] > 0))]
samples_cleaned
# Out:
#               id                datetime        variable   value
# 1        AS14.01 2014-02-26 13:00:00.000            mood   6.000
# 2        AS14.01 2014-02-26 15:00:00.000            mood   6.000
# 3        AS14.01 2014-02-26 18:00:00.000            mood   6.000
# 4        AS14.01 2014-02-26 21:00:00.000            mood   7.000
# 5        AS14.01 2014-02-27 09:00:00.000            mood   6.000
# ...          ...                     ...             ...     ...
# 2770399  AS14.30 2014-04-11 07:51:16.948  appCat.weather   8.032
# 2772465  AS14.30 2014-04-19 11:00:32.747  appCat.weather   3.008
# 2774026  AS14.30 2014-04-26 10:19:07.434  appCat.weather   7.026
# 2774133  AS14.30 2014-04-27 00:44:48.450  appCat.weather  23.033
# 2784435  AS14.32 2014-04-07 18:25:14.036  appCat.weather  22.431
#
# [376865 rows x 4 columns]

# %% [markdown]
# ## Remove outliers

# %%
## Todo

# %% [markdown]
# ## Pivot the data to a time indexed data frame
# https://pandas.pydata.org/docs/user_guide/reshaping.html

# %%
vdata = samples_cleaned.pivot(index="datetime", columns=["id", "variable"], values="value")
vdata
# Out:
# id                      AS14.01 AS14.02 AS14.03 AS14.05 AS14.06 AS14.07  \
# variable                   mood    mood    mood    mood    mood    mood
# datetime
# 2014-02-17 07:00:52.197     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 07:12:13.631     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 07:49:19.635     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 08:57:16.313     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-02-17 08:58:58.471     NaN     NaN     NaN     NaN     NaN     NaN
# ...                         ...     ...     ...     ...     ...     ...
# 2014-06-08 11:03:34.453     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-08 11:04:20.233     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-08 11:04:36.299     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-08 11:04:46.335     NaN     NaN     NaN     NaN     NaN     NaN
# 2014-06-09 00:00:00.000     NaN     NaN     NaN     NaN     NaN     NaN
#
# id                      AS14.08 AS14.09 AS14.12 AS14.13  ...        AS14.06  \
# variable                   mood    mood    mood    mood  ... appCat.weather
# datetime                                                 ...
# 2014-02-17 07:00:52.197     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 07:12:13.631     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 07:49:19.635     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 08:57:16.313     NaN     NaN     NaN     NaN  ...            NaN
# 2014-02-17 08:58:58.471     NaN     NaN     NaN     NaN  ...            NaN
# ...                         ...     ...     ...     ...  ...            ...
# 2014-06-08 11:03:34.453     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-08 11:04:20.233     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-08 11:04:36.299     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-08 11:04:46.335     NaN     NaN     NaN     NaN  ...            NaN
# 2014-06-09 00:00:00.000     NaN     NaN     NaN     NaN  ...            NaN
#
# id                             AS14.09        AS14.12        AS14.16  \
# variable                appCat.weather appCat.weather appCat.weather
# datetime
# 2014-02-17 07:00:52.197            NaN            NaN            NaN
# 2014-02-17 07:12:13.631            NaN            NaN            NaN
# 2014-02-17 07:49:19.635            NaN            NaN            NaN
# 2014-02-17 08:57:16.313            NaN            NaN            NaN
# 2014-02-17 08:58:58.471            NaN            NaN            NaN
# ...                                ...            ...            ...
# 2014-06-08 11:03:34.453            NaN            NaN            NaN
# 2014-06-08 11:04:20.233            NaN            NaN            NaN
# 2014-06-08 11:04:36.299            NaN            NaN            NaN
# 2014-06-08 11:04:46.335            NaN            NaN            NaN
# 2014-06-09 00:00:00.000            NaN            NaN            NaN
#
# id                             AS14.25        AS14.26        AS14.27  \
# variable                appCat.weather appCat.weather appCat.weather
# datetime
# 2014-02-17 07:00:52.197            NaN            NaN            NaN
# 2014-02-17 07:12:13.631            NaN            NaN            NaN
# 2014-02-17 07:49:19.635            NaN            NaN            NaN
# 2014-02-17 08:57:16.313            NaN            NaN            NaN
# 2014-02-17 08:58:58.471            NaN            NaN            NaN
# ...                                ...            ...            ...
# 2014-06-08 11:03:34.453            NaN            NaN            NaN
# 2014-06-08 11:04:20.233            NaN            NaN            NaN
# 2014-06-08 11:04:36.299            NaN            NaN            NaN
# 2014-06-08 11:04:46.335            NaN            NaN            NaN
# 2014-06-09 00:00:00.000            NaN            NaN            NaN
#
# id                             AS14.28        AS14.30        AS14.32
# variable                appCat.weather appCat.weather appCat.weather
# datetime
# 2014-02-17 07:00:52.197            NaN            NaN            NaN
# 2014-02-17 07:12:13.631            NaN            NaN            NaN
# 2014-02-17 07:49:19.635            NaN            NaN            NaN
# 2014-02-17 08:57:16.313            NaN            NaN            NaN
# 2014-02-17 08:58:58.471            NaN            NaN            NaN
# ...                                ...            ...            ...
# 2014-06-08 11:03:34.453            NaN            NaN            NaN
# 2014-06-08 11:04:20.233            NaN            NaN            NaN
# 2014-06-08 11:04:36.299            NaN            NaN            NaN
# 2014-06-08 11:04:46.335            NaN            NaN            NaN
# 2014-06-09 00:00:00.000            NaN            NaN            NaN
#
# [336903 rows x 464 columns]

# %% [markdown]
# ## Make features
# More feature ideas:
# - weekday vs. weekend day
# - day of the week
# - recent values from patient-reported data
# - relevant app usage data
# - use weighted window for aggregated features from the past days
# - did patient enter data (mood/valence/arousal) today
#
# To do feature engineering:
# - missing mood values: either
#    - remove timespans with no mood data: keep only the longest continuous timespan with mood data
#    - only remove outside timespans with no mood data, and *backfill* (NOT *interpolate*) inside (seems reasonable for most patient, except maybe the last two)
#
# To do data cleaning:
# - discard outliers
#
# To do train:
# - retrain on whole train partition after CV

# %%
ids = list(samples["id"].unique())
longest_allowed_gap = 2

d = {}
for id in ids:
    d[(id, "mood_1D")] = vdata.loc[:, (id , 'mood')].resample('D').mean().fillna(method='ffill', limit=longest_allowed_gap)
    d[(id, "valence_1D")] = vdata.loc[:, (id , 'circumplex.valence')].resample('D').mean().fillna(method='ffill')
    d[(id, "arousal_1D")] = vdata.loc[:, (id , 'circumplex.arousal')].resample('D').mean().fillna(method='ffill')

    d[(id, "dayofweek")] = 0

    d[(id, "social_1D")] = vdata.loc[:, (id , 'appCat.social')].resample('D').sum()
    d[(id, "screen_1D")] = vdata.loc[:, (id , 'screen')].resample('D').sum()
    d[(id, "call_1D")] = vdata.loc[:, (id , 'call')].resample('D').sum()
    d[(id, "activity_1D")] = vdata.loc[:, (id , 'activity')].resample('D').sum()

    d[(id, "mood_rolling_3D")] = vdata.loc[:, (id , 'mood')].resample('D').mean().fillna(method='ffill').rolling('3D').mean()
    d[(id, "valence_rolling_3D")] = vdata.loc[:, (id , 'circumplex.valence')].resample('D').mean().fillna(method='ffill').rolling('3D').mean() 
    d[(id, "arousal_rolling_3D")] = vdata.loc[:, (id , 'circumplex.arousal')].resample('D').mean().fillna(method='ffill').rolling('3D').mean()
    
    d[(id, "social_rolling_3D")] = vdata.loc[:, (id , 'appCat.social')].rolling('3D').sum().resample('D').mean() / 3
    d[(id, "screen_rolling_3D")] = vdata.loc[:, (id , 'screen')].rolling('3D').sum().resample('D').mean() / 3
    d[(id, "call_rolling_3D")] = vdata.loc[:, (id , 'call')].rolling('3D').sum().resample('D').mean() / 3
    d[(id, "activity_rolling_3D")] = vdata.loc[:, (id , 'activity')].rolling('3D').sum().resample('D').mean() / 3
    
    
    # pad NaN sum values with zeros
    for t in ['social_1D', 'screen_1D', 'call_1D', 'activity_1D' ]:
        d[(id, t)][d[(id, t)].isnull()] = 0
    for t in ['social_rolling_3D', 'screen_rolling_3D', 'call_rolling_3D', 'activity_rolling_3D' ]:
        d[(id, t)][d[(id, t)].isnull()] = 0
        
    d[(id, "target")] = d[(id, "mood_1D")].shift(-1)
    
features = pd.DataFrame(d)

for id in ids:
    features.loc[:, (id, 'dayofweek')] = features.index.dayofweek
    
feature_list = features['AS14.01'].columns.tolist()
features
# Out:
#            AS14.01                                                      \
#            mood_1D valence_1D arousal_1D dayofweek social_1D screen_1D
# datetime
# 2014-02-17     NaN        NaN        NaN         0       0.0       0.0
# 2014-02-18     NaN        NaN        NaN         1       0.0       0.0
# 2014-02-19     NaN        NaN        NaN         2       0.0       0.0
# 2014-02-20     NaN        NaN        NaN         3       0.0       0.0
# 2014-02-21     NaN        NaN        NaN         4       0.0       0.0
# ...            ...        ...        ...       ...       ...       ...
# 2014-06-05     NaN        1.0       -0.5         3       0.0       0.0
# 2014-06-06     NaN        1.0       -0.5         4       0.0       0.0
# 2014-06-07     NaN        1.0       -0.5         5       0.0       0.0
# 2014-06-08     NaN        1.0       -0.5         6       0.0       0.0
# 2014-06-09     NaN        1.0       -0.5         0       0.0       0.0
#
#                                                                    ...  \
#            call_1D activity_1D mood_rolling_3D valence_rolling_3D  ...
# datetime                                                           ...
# 2014-02-17     2.0         0.0             NaN                NaN  ...
# 2014-02-18     1.0         0.0             NaN                NaN  ...
# 2014-02-19     7.0         0.0             NaN                NaN  ...
# 2014-02-20     2.0         0.0             NaN                NaN  ...
# 2014-02-21     0.0         0.0             NaN                NaN  ...
# ...            ...         ...             ...                ...  ...
# 2014-06-05     0.0         0.0             8.0                1.0  ...
# 2014-06-06     0.0         0.0             8.0                1.0  ...
# 2014-06-07     0.0         0.0             8.0                1.0  ...
# 2014-06-08     0.0         0.0             8.0                1.0  ...
# 2014-06-09     0.0         0.0             8.0                1.0  ...
#
#            AS14.33                                                 \
#            call_1D activity_1D mood_rolling_3D valence_rolling_3D
# datetime
# 2014-02-17    13.0         0.0             NaN                NaN
# 2014-02-18     5.0         0.0             NaN                NaN
# 2014-02-19     5.0         0.0             NaN                NaN
# 2014-02-20     6.0         0.0             NaN                NaN
# 2014-02-21     4.0         0.0             NaN                NaN
# ...            ...         ...             ...                ...
# 2014-06-05     0.0         0.0             7.0                1.0
# 2014-06-06     0.0         0.0             7.0                1.0
# 2014-06-07     0.0         0.0             7.0                1.0
# 2014-06-08     0.0         0.0             7.0                1.0
# 2014-06-09     0.0         0.0             7.0                1.0
#
#                                                                    \
#            arousal_rolling_3D social_rolling_3D screen_rolling_3D
# datetime
# 2014-02-17                NaN               0.0               0.0
# 2014-02-18                NaN               0.0               0.0
# 2014-02-19                NaN               0.0               0.0
# 2014-02-20                NaN               0.0               0.0
# 2014-02-21                NaN               0.0               0.0
# ...                       ...               ...               ...
# 2014-06-05               -2.0               0.0               0.0
# 2014-06-06               -2.0               0.0               0.0
# 2014-06-07               -2.0               0.0               0.0
# 2014-06-08               -2.0               0.0               0.0
# 2014-06-09               -2.0               0.0               0.0
#
#
#            call_rolling_3D activity_rolling_3D target
# datetime
# 2014-02-17        2.883041                 0.0    NaN
# 2014-02-18        5.401709                 0.0    NaN
# 2014-02-19        7.397101                 0.0    NaN
# 2014-02-20        6.935065                 0.0    NaN
# 2014-02-21        4.791667                 0.0    NaN
# ...                    ...                 ...    ...
# 2014-06-05        0.000000                 0.0    NaN
# 2014-06-06        0.000000                 0.0    NaN
# 2014-06-07        0.000000                 0.0    NaN
# 2014-06-08        0.000000                 0.0    NaN
# 2014-06-09        0.000000                 0.0    NaN
#
# [113 rows x 432 columns]

# %%
def longest_continuous_stretch(x):
    # pad with np.nan
    x = np.append(np.nan, np.append(x, np.nan))
    # find where null
    w = np.where(np.isnan(x))[0]
    # diff to find length of stretch
    # argmax to find where largest stretch
    a = np.diff(w).argmax()
    # return original positions of boundary nulls
    return w[[a, a + 1]] + np.array([0, -2])

# %%
id = 'AS14.01'
print(f"ID: {id}")

[start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
x = features.iloc[start:end-longest_allowed_gap+1][id][feature_list]
y = features.iloc[start:end-longest_allowed_gap+1][id]['target']

# Discard the first and last point because we don't have the 3D averages
x = x[1:-1]
y = y[1:-1]

x['target_binary'] = np.where(y > x['mood_1D'].mean(), 1, 0)

fig, axs = plt.subplots(nrows=9, ncols=1, figsize=(10, 20), sharex=True)
# ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MONDAY))
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%a %b %d'))

fig.suptitle(id)

sns.lineplot(ax=axs[0], data=x['mood_1D'], marker='o', label='mood, day mean')
#g.axhline(x['mood_1D'].mean())
sns.lineplot(ax=axs[0], data=x['target'], marker='o', label='target, next day mean')

sns.lineplot(ax=axs[1], data=x['dayofweek'], marker='o', label='day of week')

sns.lineplot(ax=axs[2], data=x['mood_1D'], marker='o', label='mood, day mean')
sns.lineplot(ax=axs[2], data=x['mood_rolling_3D'], label='mood, 3-day rolling mean')

sns.lineplot(ax=axs[3], data=x['valence_1D'], marker='o', label='valence, day mean')
sns.lineplot(ax=axs[3], data=x['valence_rolling_3D'], label='valence, 3-day rolling mean')

sns.lineplot(ax=axs[4], data=x['arousal_1D'], marker='o', label='arousal, day mean')
sns.lineplot(ax=axs[4], data=x['arousal_rolling_3D'], label='arousal, 3-day rolling mean')

sns.lineplot(ax=axs[5], data=x['social_1D'], marker='o', label='social, day sum')
sns.lineplot(ax=axs[5], data=x['social_rolling_3D'], label='social, 3-day rolling mean');

sns.lineplot(ax=axs[6], data=x['screen_1D'], marker='o', label='screen, day sum')
sns.lineplot(ax=axs[6], data=x['screen_rolling_3D'], label='screen, 3-day rolling mean');

sns.lineplot(ax=axs[7], data=x['call_1D'], marker='o', label='call, day sum')
sns.lineplot(ax=axs[7], data=x['call_rolling_3D'], label='call, 3-day rolling mean');

sns.lineplot(ax=axs[8], data=x['activity_1D'], marker='o', label='activity, day sum')
sns.lineplot(ax=axs[8], data=x['activity_rolling_3D'], label='activity, 3-day rolling mean');
# Out:
# ID: AS14.01

# %%
x.plot(subplots=True, figsize=(6, 12), title=id);

# %%
id = 'AS14.03'
print(f"ID: {id}")

[start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
x = features.iloc[start:end-longest_allowed_gap+1][id][feature_list]
y = features.iloc[start:end-longest_allowed_gap+1][id]['target']

# Discard the first and last point because we don't have the 3D averages
x = x[1:-1]
y = y[1:-1]

fig, axs = plt.subplots(nrows=9, ncols=1, figsize=(10, 20), sharex=True)
# ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MONDAY))
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%a %b %d'))

fig.suptitle('Features')

sns.lineplot(ax=axs[0], data=x['mood_1D'], marker='o', label='mood, day mean')
sns.lineplot(ax=axs[0], data=x['target'], marker='o', label='target, next day mean')

sns.lineplot(ax=axs[1], data=x['dayofweek'], marker='o', label='day of week')

sns.lineplot(ax=axs[2], data=x['mood_1D'], marker='o', label='mood, day mean')
sns.lineplot(ax=axs[2], data=x['mood_rolling_3D'], label='mood, 3-day rolling mean')

sns.lineplot(ax=axs[3], data=x['valence_1D'], marker='o', label='valence, day mean')
sns.lineplot(ax=axs[3], data=x['valence_rolling_3D'], label='valence, 3-day rolling mean')

sns.lineplot(ax=axs[4], data=x['arousal_1D'], marker='o', label='arousal, day mean')
sns.lineplot(ax=axs[4], data=x['arousal_rolling_3D'], label='arousal, 3-day rolling mean')

sns.lineplot(ax=axs[5], data=x['social_1D'], marker='o', label='social, day sum')
sns.lineplot(ax=axs[5], data=x['social_rolling_3D'], label='social, 3-day rolling mean');

sns.lineplot(ax=axs[6], data=x['screen_1D'], marker='o', label='screen, day sum')
sns.lineplot(ax=axs[6], data=x['screen_rolling_3D'], label='screen, 3-day rolling mean');

sns.lineplot(ax=axs[7], data=x['call_1D'], marker='o', label='call, day sum')
sns.lineplot(ax=axs[7], data=x['call_rolling_3D'], label='call, 3-day rolling mean');

sns.lineplot(ax=axs[8], data=x['activity_1D'], marker='o', label='activity, day sum')
sns.lineplot(ax=axs[8], data=x['activity_rolling_3D'], label='activity, 3-day rolling mean');
# Out:
# ID: AS14.03

# %%
x.plot(subplots=True, figsize=(6, 12), title=id);

# %%
features.index
# Out:
# DatetimeIndex(['2014-02-17', '2014-02-18', '2014-02-19', '2014-02-20',
#                '2014-02-21', '2014-02-22', '2014-02-23', '2014-02-24',
#                '2014-02-25', '2014-02-26',
#                ...
#                '2014-05-31', '2014-06-01', '2014-06-02', '2014-06-03',
#                '2014-06-04', '2014-06-05', '2014-06-06', '2014-06-07',
#                '2014-06-08', '2014-06-09'],
#               dtype='datetime64[ns]', name='datetime', length=113, freq='D')

# %%
feature_list
# Out:
# ['mood_1D',
#  'valence_1D',
#  'arousal_1D',
#  'dayofweek',
#  'social_1D',
#  'screen_1D',
#  'call_1D',
#  'activity_1D',
#  'mood_rolling_3D',
#  'valence_rolling_3D',
#  'arousal_rolling_3D',
#  'social_rolling_3D',
#  'screen_rolling_3D',
#  'call_rolling_3D',
#  'activity_rolling_3D',
#  'target']

# %%
all_results = pd.DataFrame(columns=['algo', 'id', 'mean', 'std', 'features'])
all_results
# Out:
# Empty DataFrame
# Columns: [algo, id, mean, std, features]
# Index: []

# %% [markdown]
# ## Toy for testing code: decision tree binary classifier, using only previous day mean mood

# %%
algo = 'decision_tree'
selected_features = ['mood_1D']

to_store = []
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target'] 

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]
    
#     print(x, x.mean())

    # Decision tree
    classifier = DecisionTreeClassifier()
    y_binary = np.where(y > x.mean()['mood_1D'], 1, 0)
    
    # Preprocess labels
    le = LabelEncoder()
    le.fit(y_binary)
    y_binary = le.transform(y_binary)
    
#     print(scaler.mean_, scaler.scale_)
#     print(x)
#     print(y)
#     print(y_binary)
    
    scores = cross_val_score(pipe, x, y_binary, cv=5)
#     print(f"Cross validation scores for {id}:")
#     print(f"{scores}")
#     print(f"{scores.mean():0.2f} accuracy with a standard deviation of {scores.std():0.2f}\n")
    
    to_store.append({'algo': algo, 'id': id, 'mean': scores.mean(), 'std': scores.std(), 'features': selected_features})
    print(f"ID: {id} accuracy: {scores.mean():0.2f}")

results = pd.DataFrame(to_store)
print(f"Mean accuracy across all patients: {results['mean'].mean():0.2f}")
# Out:
# ID: AS14.01 accuracy: 0.63
# ID: AS14.02 accuracy: 0.56
# ID: AS14.03 accuracy: 0.39
# ID: AS14.05 accuracy: 0.79
# ID: AS14.06 accuracy: 0.47
# ID: AS14.07 accuracy: 0.30
# ID: AS14.08 accuracy: 0.48
# ID: AS14.09 accuracy: 0.47
# ID: AS14.12 accuracy: 0.40
# ID: AS14.13 accuracy: 0.61
# ID: AS14.14 accuracy: 0.58
# ID: AS14.15 accuracy: 0.72
# ID: AS14.16 accuracy: 0.54
# ID: AS14.17 accuracy: 0.43
# ID: AS14.19 accuracy: 0.41
# ID: AS14.20 accuracy: 0.60
# ID: AS14.23 accuracy: 0.51
# ID: AS14.24 accuracy: 0.60
# ID: AS14.25 accuracy: 0.70
# ID: AS14.26 accuracy: 0.48
# ID: AS14.27 accuracy: 0.61
# ID: AS14.28 accuracy: 0.30
# ID: AS14.29 accuracy: 0.60
# ID: AS14.30 accuracy: 0.71
# ID: AS14.31 accuracy: 0.71
# ID: AS14.32 accuracy: 0.60
# ID: AS14.33 accuracy: 0.50
# Mean accuracy across all patients: 0.55

# %% [markdown]
# ## This is how you cheat with thresholds

# %%
algo = 'decision_tree'
selected_features = ['mood_1D']
my_threshold_look_at_me_getting_results_just_dont_mind_the_pink_warnings = 6.5

to_store = []
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target'] 

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]

    # Decision tree
    classifier = DecisionTreeClassifier()
    scaler = StandardScaler(with_std=False, with_mean=False).fit(x)
    pipe = Pipeline(steps=[("scaler", scaler), ("classifier", classifier)])   
    y_binary = np.where(y > my_threshold_look_at_me_getting_results_just_dont_mind_the_pink_warnings, 1, 0)
    
    # Preprocess labels
    le = LabelEncoder()
    le.fit(y_binary)
    y_binary = le.transform(y_binary)
    
#     print(scaler.mean_, scaler.scale_)
#     print(x)
#     print(y)
#     print(y_binary)
    
    scores = cross_val_score(pipe, x, y_binary, cv=5)
#     print(f"Cross validation scores for {id}:")
#     print(f"{scores}")
#     print(f"{scores.mean():0.2f} accuracy with a standard deviation of {scores.std():0.2f}\n")
    
    to_store.append({'algo': algo, 'id': id, 'mean': scores.mean(), 'std': scores.std(), 'features': selected_features})
    print(f"ID: {id} accuracy: {scores.mean():0.2f}")

results = pd.DataFrame(to_store)
print(f"Mean accuracy across all patients: {results['mean'].mean():0.2f} TA-DA!!!")
# Out:
# ID: AS14.01 accuracy: 0.61
# ID: AS14.02 accuracy: 0.54
# ID: AS14.03 accuracy: 1.00
# ID: AS14.05 accuracy: 0.81
# ID: AS14.06 accuracy: 0.80
# ID: AS14.07 accuracy: 0.58
# ID: AS14.08 accuracy: 0.62
# ID: AS14.09 accuracy: 0.53
# ID: AS14.12 accuracy: 0.57
# ID: AS14.13 accuracy: 0.67
# ID: AS14.14 accuracy: 0.67
# ID: AS14.15 accuracy: 0.83
# ID: AS14.16 accuracy: 0.48
# ID: AS14.17 accuracy: 1.00
# ID: AS14.19 accuracy: 0.61
# ID: AS14.20 accuracy: 0.80
# ID: AS14.23 accuracy: 0.82
# ID: AS14.24 accuracy: 0.79
# ID: AS14.25 accuracy: 0.58
# ID: AS14.26 accuracy: 0.57
# ID: AS14.27 accuracy: 0.76
# ID: AS14.28 accuracy: 0.81
# ID: AS14.29 accuracy: 0.81
# ID: AS14.30 accuracy: 1.00
# ID: AS14.31 accuracy: 0.93
# ID: AS14.32 accuracy: 0.95
# ID: AS14.33 accuracy: 0.63
# Mean accuracy across all patients: 0.73 TA-DA!!!
# /Users/adele/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /Users/adele/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# /Users/adele/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /Users/adele/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ## Random Forest classifier, using only previous day mean mood

# %%
algo = 'random_forest_1'
selected_features = ['mood_1D']

to_store = []
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target']

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]

    # Grid search parameters
    param_grid = {
        "classifier__n_estimators": [50,100,150,200,250],
        'classifier__max_depth':[2, 3, 4, 5, 6]
    }

    # Random Forest classifier grid search to find best parameters
    scaler = StandardScaler(with_std=False).fit(x)
    classifier = RandomForestClassifier(random_state=42)
    pipe = Pipeline(steps=[("scaler", scaler), ("classifier", classifier)])
    search = GridSearchCV(pipe, param_grid=param_grid, cv=4, scoring='accuracy', n_jobs=8)
    y_binary = np.where(y > scaler.mean_[0], 1, 0)
    
    # Make labels categorical
    le = LabelEncoder()
    le.fit(y_binary)
    y_binary = le.transform(y_binary)

    search.fit(x, y_binary)
    best_params = search.best_params_ 
    print(f"Parameters: {best_params}")

    # Train and cross validate using best parameters obtained from grid search
    classifier = RandomForestClassifier(random_state=42, 
                                        max_depth=best_params['classifier__max_depth'],
                                        n_estimators=best_params['classifier__n_estimators'])
    scores = cross_val_score(pipe, x, y_binary, cv=4)
    predictions = cross_val_predict(pipe, x, y_binary, cv=4)
#     print(f"Cross validation scores:")
#     print(f"{scores}")
#     print(f"{scores.mean():0.2f} accuracy with a standard deviation of {scores.std():0.2f}\n")
    
    to_store.append({'algo': algo, 'id': id, 'mean': scores.mean(), 'std': scores.std(), 'features': selected_features})
    print(f"ID: {id} accuracy: {scores.mean():0.2f}")

results = pd.DataFrame(to_store)
print(f"Mean accuracy across all patients: {results['mean'].mean():0.2f}")
# Out:
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.01 accuracy: 0.63
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 50}
# ID: AS14.02 accuracy: 0.62
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 100}
# ID: AS14.03 accuracy: 0.48
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 150}
# ID: AS14.05 accuracy: 0.84
# Parameters: {'classifier__max_depth': 4, 'classifier__n_estimators': 50}
# ID: AS14.06 accuracy: 0.50
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 100}
# ID: AS14.07 accuracy: 0.39
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.08 accuracy: 0.50
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 200}
# ID: AS14.09 accuracy: 0.30
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.12 accuracy: 0.36
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.13 accuracy: 0.63
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.14 accuracy: 0.53
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.15 accuracy: 0.72
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 50}
# ID: AS14.16 accuracy: 0.46
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.17 accuracy: 0.55
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 100}
# ID: AS14.19 accuracy: 0.43
# Parameters: {'classifier__max_depth': 4, 'classifier__n_estimators': 50}
# ID: AS14.20 accuracy: 0.53
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.23 accuracy: 0.61
# Parameters: {'classifier__max_depth': 5, 'classifier__n_estimators': 50}
# ID: AS14.24 accuracy: 0.64
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 50}
# ID: AS14.25 accuracy: 0.55
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.26 accuracy: 0.58
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 50}
# ID: AS14.27 accuracy: 0.62
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.28 accuracy: 0.32
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.29 accuracy: 0.50
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.30 accuracy: 0.71
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.31 accuracy: 0.69
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 100}
# ID: AS14.32 accuracy: 0.65
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.33 accuracy: 0.50
# Mean accuracy across all patients: 0.55

# %%
all_results = pd.concat([all_results, results])
all_results
# Out:
#                algo       id      mean       std   features
# 0   random_forest_1  AS14.01  0.629545  0.106285  [mood_1D]
# 1   random_forest_1  AS14.02  0.616667  0.076376  [mood_1D]
# 2   random_forest_1  AS14.03  0.479167  0.048323  [mood_1D]
# 3   random_forest_1  AS14.05  0.841346  0.098411  [mood_1D]
# 4   random_forest_1  AS14.06  0.500000  0.078730  [mood_1D]
# 5   random_forest_1  AS14.07  0.390152  0.069536  [mood_1D]
# 6   random_forest_1  AS14.08  0.500000  0.100000  [mood_1D]
# 7   random_forest_1  AS14.09  0.295455  0.075378  [mood_1D]
# 8   random_forest_1  AS14.12  0.363889  0.150180  [mood_1D]
# 9   random_forest_1  AS14.13  0.628205  0.058751  [mood_1D]
# 10  random_forest_1  AS14.14  0.530303  0.108203  [mood_1D]
# 11  random_forest_1  AS14.15  0.721154  0.038339  [mood_1D]
# 12  random_forest_1  AS14.16  0.461538  0.094211  [mood_1D]
# 13  random_forest_1  AS14.17  0.545455  0.064282  [mood_1D]
# 14  random_forest_1  AS14.19  0.431818  0.099066  [mood_1D]
# 15  random_forest_1  AS14.20  0.534091  0.067228  [mood_1D]
# 16  random_forest_1  AS14.23  0.608333  0.068211  [mood_1D]
# 17  random_forest_1  AS14.24  0.642857  0.051835  [mood_1D]
# 18  random_forest_1  AS14.25  0.553571  0.269045  [mood_1D]
# 19  random_forest_1  AS14.26  0.582721  0.068064  [mood_1D]
# 20  random_forest_1  AS14.27  0.615909  0.161907  [mood_1D]
# 21  random_forest_1  AS14.28  0.322222  0.128140  [mood_1D]
# 22  random_forest_1  AS14.29  0.500000  0.096424  [mood_1D]
# 23  random_forest_1  AS14.30  0.710227  0.043643  [mood_1D]
# 24  random_forest_1  AS14.31  0.690909  0.078203  [mood_1D]
# 25  random_forest_1  AS14.32  0.650000  0.150000  [mood_1D]
# 26  random_forest_1  AS14.33  0.500000  0.101639  [mood_1D]

# %% [markdown]
# ## Random Forest classifier, using all available features

# %%
feature_list
# Out:
# ['mood_1D',
#  'valence_1D',
#  'arousal_1D',
#  'dayofweek',
#  'social_1D',
#  'screen_1D',
#  'call_1D',
#  'activity_1D',
#  'mood_rolling_3D',
#  'valence_rolling_3D',
#  'arousal_rolling_3D',
#  'social_rolling_3D',
#  'screen_rolling_3D',
#  'call_rolling_3D',
#  'activity_rolling_3D',
#  'target']

# %%
algo = 'random_forest_2'
selected_features = feature_list[:-1]

to_store = []
predictions = {}
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target']

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]


    # Grid search parameters
    param_grid = {
        "classifier__n_estimators": [50,100,150,200,250],
        'classifier__max_depth':[2, 3, 4, 5, 6]
    }

    # Random Forest classifier grid search to find best parameters
    scaler = StandardScaler(with_std=False).fit(x)
    classifier = RandomForestClassifier(random_state=42)
    pipe = Pipeline(steps=[("scaler", scaler), ("classifier", classifier)])
    search = GridSearchCV(pipe, param_grid=param_grid, cv=4, scoring='accuracy', n_jobs=8)
    y_binary = np.where(y > scaler.mean_[0], 1, 0)
    
    # Make labels categorical
    le = LabelEncoder()
    le.fit(y_binary)
    y_binary = le.transform(y_binary)

    search.fit(x, y_binary)
    best_params = search.best_params_ 
    print(f"Parameters: {best_params}")

    # Train and cross validate using best parameters obtained from grid search
    classifier = RandomForestClassifier(random_state=42, 
                                        max_depth=best_params['classifier__max_depth'],
                                        n_estimators=best_params['classifier__n_estimators'])
    scores = cross_val_score(pipe, x, y_binary, cv=4)
#     print(f"Cross validation scores:")
#     print(f"{scores}")
#     print(f"{scores.mean():0.2f} accuracy with a standard deviation of {scores.std():0.2f}\n")

 
    to_store.append({'algo': algo, 'id': id, 'mean': scores.mean(), 'std': scores.std(), 'features': selected_features})
    print(f"ID: {id} accuracy: {scores.mean():0.2f}")

results = pd.DataFrame(to_store)
print(f"Mean accuracy across all patients: {results['mean'].mean():0.2f}")
# Out:
# Parameters: {'classifier__max_depth': 4, 'classifier__n_estimators': 50}
# ID: AS14.01 accuracy: 0.79
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 150}
# ID: AS14.02 accuracy: 0.54
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.03 accuracy: 0.52
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 50}
# ID: AS14.05 accuracy: 0.80
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 150}
# ID: AS14.06 accuracy: 0.30
# Parameters: {'classifier__max_depth': 4, 'classifier__n_estimators': 250}
# ID: AS14.07 accuracy: 0.39
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 200}
# ID: AS14.08 accuracy: 0.65
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.09 accuracy: 0.41
# Parameters: {'classifier__max_depth': 5, 'classifier__n_estimators': 250}
# ID: AS14.12 accuracy: 0.47
# Parameters: {'classifier__max_depth': 4, 'classifier__n_estimators': 50}
# ID: AS14.13 accuracy: 0.53
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 150}
# ID: AS14.14 accuracy: 0.60
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.15 accuracy: 0.76
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.16 accuracy: 0.62
# Parameters: {'classifier__max_depth': 4, 'classifier__n_estimators': 50}
# ID: AS14.17 accuracy: 0.41
# Parameters: {'classifier__max_depth': 5, 'classifier__n_estimators': 150}
# ID: AS14.19 accuracy: 0.61
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 100}
# ID: AS14.20 accuracy: 0.44
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 200}
# ID: AS14.23 accuracy: 0.47
# Parameters: {'classifier__max_depth': 5, 'classifier__n_estimators': 50}
# ID: AS14.24 accuracy: 0.64
# Parameters: {'classifier__max_depth': 4, 'classifier__n_estimators': 200}
# ID: AS14.25 accuracy: 0.55
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.26 accuracy: 0.66
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 50}
# ID: AS14.27 accuracy: 0.49
# Parameters: {'classifier__max_depth': 5, 'classifier__n_estimators': 250}
# ID: AS14.28 accuracy: 0.46
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 200}
# ID: AS14.29 accuracy: 0.57
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 200}
# ID: AS14.30 accuracy: 0.48
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.31 accuracy: 0.67
# Parameters: {'classifier__max_depth': 3, 'classifier__n_estimators': 200}
# ID: AS14.32 accuracy: 0.47
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.33 accuracy: 0.50
# Mean accuracy across all patients: 0.55

# %%
all_results = pd.concat([all_results, results])
all_results
# Out:
#                algo       id      mean       std  \
# 0   random_forest_1  AS14.01  0.629545  0.106285
# 1   random_forest_1  AS14.02  0.616667  0.076376
# 2   random_forest_1  AS14.03  0.479167  0.048323
# 3   random_forest_1  AS14.05  0.841346  0.098411
# 4   random_forest_1  AS14.06  0.500000  0.078730
# 5   random_forest_1  AS14.07  0.390152  0.069536
# 6   random_forest_1  AS14.08  0.500000  0.100000
# 7   random_forest_1  AS14.09  0.295455  0.075378
# 8   random_forest_1  AS14.12  0.363889  0.150180
# 9   random_forest_1  AS14.13  0.628205  0.058751
# 10  random_forest_1  AS14.14  0.530303  0.108203
# 11  random_forest_1  AS14.15  0.721154  0.038339
# 12  random_forest_1  AS14.16  0.461538  0.094211
# 13  random_forest_1  AS14.17  0.545455  0.064282
# 14  random_forest_1  AS14.19  0.431818  0.099066
# 15  random_forest_1  AS14.20  0.534091  0.067228
# 16  random_forest_1  AS14.23  0.608333  0.068211
# 17  random_forest_1  AS14.24  0.642857  0.051835
# 18  random_forest_1  AS14.25  0.553571  0.269045
# 19  random_forest_1  AS14.26  0.582721  0.068064
# 20  random_forest_1  AS14.27  0.615909  0.161907
# 21  random_forest_1  AS14.28  0.322222  0.128140
# 22  random_forest_1  AS14.29  0.500000  0.096424
# 23  random_forest_1  AS14.30  0.710227  0.043643
# 24  random_forest_1  AS14.31  0.690909  0.078203
# 25  random_forest_1  AS14.32  0.650000  0.150000
# 26  random_forest_1  AS14.33  0.500000  0.101639
# 0   random_forest_2  AS14.01  0.790909  0.037483
# 1   random_forest_2  AS14.02  0.544444  0.172670
# 2   random_forest_2  AS14.03  0.522727  0.090116
# 3   random_forest_2  AS14.05  0.802885  0.140250
# 4   random_forest_2  AS14.06  0.295455  0.134456
# 5   random_forest_2  AS14.07  0.388258  0.122785
# 6   random_forest_2  AS14.08  0.650000  0.055277
# 7   random_forest_2  AS14.09  0.409091  0.198132
# 8   random_forest_2  AS14.12  0.466667  0.154760
# 9   random_forest_2  AS14.13  0.532051  0.099926
# 10  random_forest_2  AS14.14  0.600379  0.038396
# 11  random_forest_2  AS14.15  0.758242  0.038657
# 12  random_forest_2  AS14.16  0.615385  0.121626
# 13  random_forest_2  AS14.17  0.409091  0.136364
# 14  random_forest_2  AS14.19  0.613636  0.162305
# 15  random_forest_2  AS14.20  0.439394  0.146116
# 16  random_forest_2  AS14.23  0.472222  0.027778
# 17  random_forest_2  AS14.24  0.642857  0.120504
# 18  random_forest_2  AS14.25  0.553571  0.105644
# 19  random_forest_2  AS14.26  0.655331  0.083123
# 20  random_forest_2  AS14.27  0.486364  0.113272
# 21  random_forest_2  AS14.28  0.458333  0.082168
# 22  random_forest_2  AS14.29  0.572727  0.069829
# 23  random_forest_2  AS14.30  0.484848  0.213201
# 24  random_forest_2  AS14.31  0.672727  0.180907
# 25  random_forest_2  AS14.32  0.475000  0.082916
# 26  random_forest_2  AS14.33  0.500000  0.101639
#
#                                              features
# 0                                           [mood_1D]
# 1                                           [mood_1D]
# 2                                           [mood_1D]
# 3                                           [mood_1D]
# 4                                           [mood_1D]
# 5                                           [mood_1D]
# 6                                           [mood_1D]
# 7                                           [mood_1D]
# 8                                           [mood_1D]
# 9                                           [mood_1D]
# 10                                          [mood_1D]
# 11                                          [mood_1D]
# 12                                          [mood_1D]
# 13                                          [mood_1D]
# 14                                          [mood_1D]
# 15                                          [mood_1D]
# 16                                          [mood_1D]
# 17                                          [mood_1D]
# 18                                          [mood_1D]
# 19                                          [mood_1D]
# 20                                          [mood_1D]
# 21                                          [mood_1D]
# 22                                          [mood_1D]
# 23                                          [mood_1D]
# 24                                          [mood_1D]
# 25                                          [mood_1D]
# 26                                          [mood_1D]
# 0   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 1   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 2   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 3   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 4   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 5   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 6   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 7   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 8   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 9   [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 10  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 11  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 12  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 13  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 14  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 15  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 16  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 17  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 18  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 19  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 20  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 21  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 22  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 23  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 24  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 25  [mood_1D, valence_1D, arousal_1D, dayofweek, s...
# 26  [mood_1D, valence_1D, arousal_1D, dayofweek, s...

# %% [markdown]
# ## All ids: Random Forest classifier, using some available features

# %%
feature_list
# Out:
# ['mood_1D',
#  'valence_1D',
#  'arousal_1D',
#  'dayofweek',
#  'social_1D',
#  'screen_1D',
#  'call_1D',
#  'activity_1D',
#  'mood_rolling_3D',
#  'valence_rolling_3D',
#  'arousal_rolling_3D',
#  'social_rolling_3D',
#  'screen_rolling_3D',
#  'call_rolling_3D',
#  'activity_rolling_3D',
#  'target']

# %%
algo = 'random_forest_3'
selected_features = [
#  'mood_1D',
 'valence_1D',
#  'arousal_1D',
#  'dayofweek',
#  'social_1D',
 'screen_1D',
#  'call_1D',
#  'activity_1D',
#  'mood_rolling_3D',
#  'valence_rolling_3D',
#  'arousal_rolling_3D',
#  'social_rolling_3D',
#  'screen_rolling_3D',
#  'call_rolling_3D',
#  'activity_rolling_3D',
]

to_store = []
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target']

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]


    # Grid search parameters
    param_grid = {
        "classifier__n_estimators": [50,100,150,200,250],
        'classifier__max_depth':[2, 3, 4, 5, 6]
    }

    # Random Forest classifier grid search to find best parameters
    scaler = StandardScaler(with_std=False).fit(x)
    classifier = RandomForestClassifier(random_state=42)
    pipe = Pipeline(steps=[("scaler", scaler), ("classifier", classifier)])
    search = GridSearchCV(pipe, param_grid=param_grid, cv=4, scoring='accuracy', n_jobs=8)
    y_binary = np.where(y > scaler.mean_[0], 1, 0)
    
    # Make labels categorical
    le = LabelEncoder()
    le.fit(y_binary)
    y_binary = le.transform(y_binary)

    search.fit(x, y_binary)
    best_params = search.best_params_ 
    print(f"Parameters: {best_params}")

    # Train and cross validate using best parameters obtained from grid search
    classifier = RandomForestClassifier(random_state=42, 
                                        max_depth=best_params['classifier__max_depth'],
                                        n_estimators=best_params['classifier__n_estimators'])
    scores = cross_val_score(pipe, x, y_binary, cv=4)
#     print(f"Cross validation scores:")
#     print(f"{scores}")
#     print(f"{scores.mean():0.2f} accuracy with a standard deviation of {scores.std():0.2f}\n")
 
 
    to_store.append({'algo': algo, 'id': id, 'mean': scores.mean(), 'std': scores.std(), 'features': selected_features})
    print(f"ID: {id} accuracy: {scores.mean():0.2f}")

results = pd.DataFrame(to_store)
print(f"Mean accuracy across all patients: {results['mean'].mean():0.2f}")
# Out:
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.01 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.02 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.03 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.05 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.06 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.07 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.08 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.09 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.12 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.13 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.14 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.15 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.16 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.17 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.19 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.20 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.23 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.24 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.25 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.26 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.27 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.28 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.29 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.30 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.31 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.32 accuracy: 1.00
# Parameters: {'classifier__max_depth': 2, 'classifier__n_estimators': 50}
# ID: AS14.33 accuracy: 1.00
# Mean accuracy across all patients: 1.00

# %%
all_results = pd.concat([all_results, results])
all_results
# Out:
#                algo       id      mean       std  \
# 0   random_forest_1  AS14.01  0.629545  0.106285
# 1   random_forest_1  AS14.02  0.616667  0.076376
# 2   random_forest_1  AS14.03  0.479167  0.048323
# 3   random_forest_1  AS14.05  0.841346  0.098411
# 4   random_forest_1  AS14.06  0.500000  0.078730
# ..              ...      ...       ...       ...
# 22  random_forest_3  AS14.29  1.000000  0.000000
# 23  random_forest_3  AS14.30  1.000000  0.000000
# 24  random_forest_3  AS14.31  1.000000  0.000000
# 25  random_forest_3  AS14.32  1.000000  0.000000
# 26  random_forest_3  AS14.33  1.000000  0.000000
#
#                                              features
# 0                                           [mood_1D]
# 1                                           [mood_1D]
# 2                                           [mood_1D]
# 3                                           [mood_1D]
# 4                                           [mood_1D]
# ..                                                ...
# 22  [valence_1D, arousal_1D, dayofweek, social_1D,...
# 23  [valence_1D, arousal_1D, dayofweek, social_1D,...
# 24  [valence_1D, arousal_1D, dayofweek, social_1D,...
# 25  [valence_1D, arousal_1D, dayofweek, social_1D,...
# 26  [valence_1D, arousal_1D, dayofweek, social_1D,...
#
# [81 rows x 5 columns]

# %% [markdown]
# ## Mean accuracy over all patients

# %%
for algo in all_results['algo'].unique():
    print(f"{algo}: {all_results[all_results['algo'] == algo].mean(numeric_only=True)}")
# Out:
# random_forest_1: mean    0.549835
# std     0.094460
# dtype: float64
# random_forest_2: mean    0.548615
# std     0.112233
# dtype: float64
# random_forest_3: mean    1.0
# std     0.0
# dtype: float64

# %%
fig, ax = plt.subplots()
sns.barplot(data=all_results, x="id", y="mean", hue="algo")
plt.xticks(rotation=45);

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

algo = 'linear_regression'
selected_features = [
'mood_1D',
'valence_1D',
'arousal_1D',
'dayofweek',
'social_1D',
'screen_1D',
'call_1D',
'activity_1D',
'mood_rolling_3D',
'valence_rolling_3D',
'arousal_rolling_3D',
'social_rolling_3D',
'screen_rolling_3D',
'call_rolling_3D',
'activity_rolling_3D'
]


to_store = []
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target'] 

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]
    
#     print(x)
#     print(y)

    # scaling
    scaler = StandardScaler().fit(x)
    # Linear regression
    regressor = linear_model.LinearRegression()
    pipe = Pipeline(steps=[("scaler", scaler), ("regressor", regressor)])
    scores = cross_val_score(pipe, x, y, cv=4, scoring='neg_mean_absolute_error')
    
    print(f"Cross validation scores for {id}:")
    print(f"{-scores}")
    print(f"{-scores.mean():0.2f} error with a standard deviation of {scores.std():0.2f}\n")
    
#     to_store.append({'algo': algo, 'id': id, 'mean': scores.mean(), 'std': scores.std(), 'features': selected_features})
#     print(f"ID: {id} accuracy: {scores.mean():0.2f}")
# Out:
# Cross validation scores for AS14.01:
# [0.60889881 0.41374795 0.51535852 0.5655209 ]
# 0.53 error with a standard deviation of 0.07
#
# Cross validation scores for AS14.02:
# [2.43216547 1.17403055 0.77736791 1.15996141]
# 1.39 error with a standard deviation of 0.62
#
# Cross validation scores for AS14.03:
# [0.71409181 0.37232715 0.27639731 0.58114708]
# 0.49 error with a standard deviation of 0.17
#
# Cross validation scores for AS14.05:
# [1.34654041 0.93746399 0.87546976 0.46499976]
# 0.91 error with a standard deviation of 0.31
#
# Cross validation scores for AS14.06:
# [0.51189272 0.5613876  0.67284988 0.40488527]
# 0.54 error with a standard deviation of 0.10
#
# Cross validation scores for AS14.07:
# [2.39198916 1.07843263 1.14331265 1.5167693 ]
# 1.53 error with a standard deviation of 0.52
#
# Cross validation scores for AS14.08:
# [0.60461794 0.49996408 0.45587094 0.79519919]
# 0.59 error with a standard deviation of 0.13
#
# Cross validation scores for AS14.09:
# [1.26196805 0.94437268 1.13946881 0.90000457]
# 1.06 error with a standard deviation of 0.15
#
# Cross validation scores for AS14.12:
# [0.69502145 0.83304287 0.47770555 0.68149309]
# 0.67 error with a standard deviation of 0.13
#
# Cross validation scores for AS14.13:
# [0.79019481 0.97836577 1.13949739 1.07323224]
# 1.00 error with a standard deviation of 0.13
#
# Cross validation scores for AS14.14:
# [7.03050111 0.58304854 0.48596804 0.62175698]
# 2.18 error with a standard deviation of 2.80
#
# Cross validation scores for AS14.15:
# [0.41574079 0.52443619 0.76459355 0.40393378]
# 0.53 error with a standard deviation of 0.14
#
# Cross validation scores for AS14.16:
# [0.58419174 0.75701761 0.3350288  0.59857591]
# 0.57 error with a standard deviation of 0.15
#
# Cross validation scores for AS14.17:
# [0.3409205  0.19355378 0.32247233 0.39340982]
# 0.31 error with a standard deviation of 0.07
#
# Cross validation scores for AS14.19:
# [1.3014002  0.4560207  4.49556975 0.94498356]
# 1.80 error with a standard deviation of 1.59
#
# Cross validation scores for AS14.20:
# [0.35151098 0.33106625 0.33733721 0.27006128]
# 0.32 error with a standard deviation of 0.03
#
# Cross validation scores for AS14.23:
# [3.84672504 1.65622372 0.5949034  0.63962204]
# 1.68 error with a standard deviation of 1.32
#
# Cross validation scores for AS14.24:
# [0.66704409 0.42853065 0.44664991 0.55199039]
# 0.52 error with a standard deviation of 0.10
#
# Cross validation scores for AS14.25:
# [1.15145437 0.91716575 1.22924192 0.74709521]
# 1.01 error with a standard deviation of 0.19
#
# Cross validation scores for AS14.26:
# [0.57182082 0.53307855 0.55909018 0.44451105]
# 0.53 error with a standard deviation of 0.05
#
# Cross validation scores for AS14.27:
# [0.66026558 0.82042776 0.88520104 1.01687171]
# 0.85 error with a standard deviation of 0.13
#
# Cross validation scores for AS14.28:
# [0.92704528 1.26334858 0.85045018 1.72021359]
# 1.19 error with a standard deviation of 0.34
#
# Cross validation scores for AS14.29:
# [1.00260012 0.50140954 0.45405353 0.88799639]
# 0.71 error with a standard deviation of 0.24
#
# Cross validation scores for AS14.30:
# [0.49735506 0.32045695 0.28366773 0.14586712]
# 0.31 error with a standard deviation of 0.13
#
# Cross validation scores for AS14.31:
# [0.62085482 0.64039303 0.43179126 0.56647711]
# 0.56 error with a standard deviation of 0.08
#
# Cross validation scores for AS14.32:
# [0.96510546 0.63127089 0.72116619 1.051961  ]
# 0.84 error with a standard deviation of 0.17
#
# Cross validation scores for AS14.33:
# [1.43378818 1.20244027 2.66796769 0.58841824]
# 1.47 error with a standard deviation of 0.76

# %%
from sklearn.ensemble import RandomForestRegressor

algo = 'random_forest_regression'
selected_features = [
 'mood_1D',
 'valence_1D',
 'arousal_1D',
 'dayofweek',
 'social_1D',
 'screen_1D',
 'call_1D',
 'activity_1D',
 'mood_rolling_3D',
 'valence_rolling_3D',
 'arousal_rolling_3D',
 'social_rolling_3D',
 'screen_rolling_3D',
 'call_rolling_3D',
 'activity_rolling_3D'
]

to_store = []
predictions = []
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target']

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]


    # Grid search parameters
    param_grid = {
        "regressor__n_estimators": [50,100,150,200,250],
        'regressor__max_depth':[2, 3, 4, 5, 6]
    }

    # Random Forest regression grid search to find best parameters
    scaler = StandardScaler().fit(x)
    regressor = RandomForestRegressor(random_state=42)
    pipe = Pipeline(steps=[("scaler", scaler), ("regressor", regressor)])
    search = GridSearchCV(pipe, param_grid=param_grid, cv=4, scoring='neg_mean_absolute_error', n_jobs=8)
    
    search.fit(x, y)
    best_params = search.best_params_ 
    print(f"Parameters: {best_params}")

    # Train and cross validate using best parameters obtained from grid search
    classifier = RandomForestClassifier(random_state=42, 
                                        max_depth=best_params['regressor__max_depth'],
                                        n_estimators=best_params['regressor__n_estimators'])
    scores = cross_val_score(pipe, x, y, cv=4)
    predictions.append(cross_val_predict(pipe, x, y, cv=4))
 
    print(f"Cross validation scores for {id}:")
    print(f"{-scores}")
    print(f"{-scores.mean():0.2f} error with a standard deviation of {scores.std():0.2f}\n")
# Out:
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.01:
# [ 0.59475528 -0.19113531 -0.00863704  0.80100168]
# 0.30 error with a standard deviation of 0.41
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 200}
# Cross validation scores for AS14.02:
# [1.66050708 0.23524336 0.24982091 0.60438343]
# 0.69 error with a standard deviation of 0.58
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.03:
# [2.02082411 0.5746411  0.13624439 0.73604477]
# 0.87 error with a standard deviation of 0.70
#
# Parameters: {'regressor__max_depth': 4, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.05:
# [ 0.87957216  2.91533808 -0.23139451  0.1189834 ]
# 0.92 error with a standard deviation of 1.22
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.06:
# [0.80812928 0.09269931 0.11387462 0.27334011]
# 0.32 error with a standard deviation of 0.29
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 200}
# Cross validation scores for AS14.07:
# [3.68716009 0.43779565 0.51290588 0.18631251]
# 1.21 error with a standard deviation of 1.44
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.08:
# [0.19312232 0.5441048  0.08736551 0.48638361]
# 0.33 error with a standard deviation of 0.19
#
# Parameters: {'regressor__max_depth': 4, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.09:
# [0.74122627 0.28406985 0.28687093 0.76831051]
# 0.52 error with a standard deviation of 0.23
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 200}
# Cross validation scores for AS14.12:
# [ 0.28432528  0.25124303 -0.22234946  0.97943664]
# 0.32 error with a standard deviation of 0.43
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.13:
# [0.2204152  0.82101337 1.28622579 4.89353816]
# 1.81 error with a standard deviation of 1.82
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.14:
# [ 1.40406233  0.86680774  0.19352666 -0.18071297]
# 0.57 error with a standard deviation of 0.61
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.15:
# [0.98787283 0.41495585 0.16650647 0.30315861]
# 0.47 error with a standard deviation of 0.31
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.16:
# [1.58684722 0.34684863 0.18775501 0.62492043]
# 0.69 error with a standard deviation of 0.54
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.17:
# [0.28568364 3.07602342 0.57765888 0.0905014 ]
# 1.01 error with a standard deviation of 1.21
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.19:
# [1.23260384 0.27477497 0.4735231  0.35379679]
# 0.58 error with a standard deviation of 0.38
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.20:
# [ 0.20478067  0.84779894 -0.11537534  0.40757436]
# 0.34 error with a standard deviation of 0.35
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.23:
# [0.22653678 2.95493614 1.68993235 0.34160448]
# 1.30 error with a standard deviation of 1.11
#
# Parameters: {'regressor__max_depth': 5, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.24:
# [-0.16486703 -0.312852    0.03369152 -0.05955275]
# -0.13 error with a standard deviation of 0.13
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 150}
# Cross validation scores for AS14.25:
# [ 0.57752802  0.03352165 -0.23525711  0.02618743]
# 0.10 error with a standard deviation of 0.30
#
# Parameters: {'regressor__max_depth': 6, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.26:
# [-0.40523623 -0.21472277 -0.3351091  -0.28368094]
# -0.31 error with a standard deviation of 0.07
#
# Parameters: {'regressor__max_depth': 6, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.27:
# [0.12398522 1.66362195 0.13999797 1.28598146]
# 0.80 error with a standard deviation of 0.68
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 200}
# Cross validation scores for AS14.28:
# [0.19483652 0.57338777 2.39552948 3.32708323]
# 1.62 error with a standard deviation of 1.29
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.29:
# [ 2.40132978  0.8035155  -0.08075282  0.17154065]
# 0.82 error with a standard deviation of 0.97
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.30:
# [ 0.16336439 -0.07231189  0.12511469  1.31204185]
# 0.38 error with a standard deviation of 0.54
#
# Parameters: {'regressor__max_depth': 3, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.31:
# [ 0.89711311 -0.03876226 -0.19734367  0.07044064]
# 0.18 error with a standard deviation of 0.42
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.32:
# [ 1.92680016 -0.10147326  1.19066942  0.79820101]
# 0.95 error with a standard deviation of 0.73
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.33:
# [0.45921453 0.28190843 0.8373181  0.03150056]
# 0.40 error with a standard deviation of 0.29

# %%
from sklearn.ensemble import RandomForestRegressor

algo = 'random_forest_regression'
selected_features = [
#  'mood_1D',
 'valence_1D',
#  'arousal_1D',
#  'dayofweek',
#  'social_1D',
#  'screen_1D',
#  'call_1D',
#  'activity_1D',
#  'mood_rolling_3D',
#  'valence_rolling_3D',
#  'arousal_rolling_3D',
#  'social_rolling_3D',
#  'screen_rolling_3D',
#  'call_rolling_3D',
#  'activity_rolling_3D'
]

to_store = []
predictions = []
for id in ids:
    [start, end] = longest_continuous_stretch(features[id]['mood_1D']) 
    x = features.iloc[start:end-longest_allowed_gap+1][id][selected_features]
    
    # align y target to resulting x series
    y = features.iloc[start:end-longest_allowed_gap+1][id]['target']

    # Discard the first and last point because we don't have the 3D averages
    x = x[1:-1]
    y = y[1:-1]


    # Grid search parameters
    param_grid = {
        "regressor__n_estimators": [50,100,150,200,250],
        'regressor__max_depth':[2, 3, 4, 5, 6]
    }

    # Random Forest regression grid search to find best parameters
    scaler = StandardScaler().fit(x)
    regressor = RandomForestRegressor(random_state=42)
    pipe = Pipeline(steps=[("scaler", scaler), ("regressor", regressor)])
    search = GridSearchCV(pipe, param_grid=param_grid, cv=4, scoring='neg_mean_absolute_error', n_jobs=8)
    
    search.fit(x, y)
    best_params = search.best_params_ 
    print(f"Parameters: {best_params}")

    # Train and cross validate using best parameters obtained from grid search
    classifier = RandomForestClassifier(random_state=42, 
                                        max_depth=best_params['regressor__max_depth'],
                                        n_estimators=best_params['regressor__n_estimators'])
    scores = cross_val_score(pipe, x, y, cv=4)
    predictions.append(cross_val_predict(pipe, x, y, cv=4))
 
    print(f"Cross validation scores for {id}:")
    print(f"{-scores}")
    print(f"{-scores.mean():0.2f} error with a standard deviation of {scores.std():0.2f}\n")
# Out:
# Parameters: {'regressor__max_depth': 4, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.01:
# [ 0.47195433 -0.57338861 -0.29423658  0.37682363]
# -0.00 error with a standard deviation of 0.44
#
# Parameters: {'regressor__max_depth': 3, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.02:
# [1.8845107  0.02349704 0.18368604 0.27017005]
# 0.59 error with a standard deviation of 0.75
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.03:
# [ 0.84853437 -0.05379628  0.10737234  0.24228672]
# 0.29 error with a standard deviation of 0.34
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.05:
# [0.92958763 1.04825377 1.17314565 0.36701565]
# 0.88 error with a standard deviation of 0.31
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.06:
# [0.58058589 0.08708491 0.76033367 0.63046531]
# 0.51 error with a standard deviation of 0.26
#
# Parameters: {'regressor__max_depth': 6, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.07:
# [1.34580335 0.4295998  0.00527284 0.53314565]
# 0.58 error with a standard deviation of 0.49
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 200}
# Cross validation scores for AS14.08:
# [ 0.66881165  0.57852342 -0.00260133  0.84918269]
# 0.52 error with a standard deviation of 0.32
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.09:
# [ 1.16683141  3.10970246  1.46596979 -0.13239652]
# 1.40 error with a standard deviation of 1.15
#
# Parameters: {'regressor__max_depth': 3, 'regressor__n_estimators': 150}
# Cross validation scores for AS14.12:
# [-0.08218165  0.41530194  1.10102319  0.86736401]
# 0.58 error with a standard deviation of 0.45
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.13:
# [0.0274524  0.02721746 1.39829587 5.03747508]
# 1.62 error with a standard deviation of 2.05
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.14:
# [0.75466741 1.26075351 0.11896998 0.24239323]
# 0.59 error with a standard deviation of 0.45
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 150}
# Cross validation scores for AS14.15:
# [-0.062697    0.14952788  0.19088272  0.2063181 ]
# 0.12 error with a standard deviation of 0.11
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.16:
# [1.04676737 1.21092359 1.26481668 0.63433414]
# 1.04 error with a standard deviation of 0.25
#
# Parameters: {'regressor__max_depth': 3, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.17:
# [0.40048862 0.93204791 0.52584132 0.49795967]
# 0.59 error with a standard deviation of 0.20
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.19:
# [1.7427872  1.42441518 0.86521234 0.18184491]
# 1.05 error with a standard deviation of 0.59
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.20:
# [ 0.02851051  1.11383794 -0.35680391  1.2675558 ]
# 0.51 error with a standard deviation of 0.69
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.23:
# [1.01533037 0.43236271 2.38204901 0.08916873]
# 0.98 error with a standard deviation of 0.87
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 200}
# Cross validation scores for AS14.24:
# [0.6142986  0.22525711 0.79870788 0.22208262]
# 0.47 error with a standard deviation of 0.25
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.25:
# [ 0.88203468 -0.11964268 -0.30690563 -0.01743484]
# 0.11 error with a standard deviation of 0.46
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.26:
# [0.17908801 0.36424704 0.14994362 0.44844428]
# 0.29 error with a standard deviation of 0.12
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 150}
# Cross validation scores for AS14.27:
# [0.24513602 1.42992698 0.02717964 1.28557478]
# 0.75 error with a standard deviation of 0.62
#
# Parameters: {'regressor__max_depth': 4, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.28:
# [0.64914349 0.2797847  1.40942561 2.98789855]
# 1.33 error with a standard deviation of 1.04
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 200}
# Cross validation scores for AS14.29:
# [3.38397887 0.23156662 0.52974734 0.50257523]
# 1.16 error with a standard deviation of 1.29
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 50}
# Cross validation scores for AS14.30:
# [ 0.1814917  -0.33227927 -0.09036628 -0.14969706]
# -0.10 error with a standard deviation of 0.18
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 100}
# Cross validation scores for AS14.31:
# [0.22116583 0.11107947 2.10741945 0.45188133]
# 0.72 error with a standard deviation of 0.81
#
# Parameters: {'regressor__max_depth': 6, 'regressor__n_estimators': 150}
# Cross validation scores for AS14.32:
# [ 0.84779835 -0.11900781  0.32738563  0.20872925]
# 0.32 error with a standard deviation of 0.35
#
# Parameters: {'regressor__max_depth': 2, 'regressor__n_estimators': 250}
# Cross validation scores for AS14.33:
# [0.28572845 0.50677528 1.56327333 0.33586317]
# 0.67 error with a standard deviation of 0.52

# %%
predictions
# Out:
# [array([6.58553333, 7.30727269, 6.49775   , 6.58553333, 6.4555    ,
#         7.30727269, 6.4555    , 7.54370731, 7.85606349, 6.4555    ,
#         6.49775   , 6.85504762, 6.62578333, 6.68555952, 6.84838095,
